# %%
import requests

import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
def get_ine_id(territory_key):
    number_part = territory_key.split('-')[-1]
    return int(number_part[:-2])

def correct_names_encoding_problems(name):
    return ''.join(chr(ord(c)) for c in name).decode('utf8')

# Normalize party name to be equal to the data related to election results
def normalize_party_names(party):
    if party == 'PCP - PEV':
        return 'PCP-PEV'
    if party == 'PNR':
        return 'P.N.R.'
    return party

# %% [markdown]
#  ### Objective: obtain the names of all candidates to president of "Câmara Municpal" in the 2013 Portuguese Local Elections. Goint to crawl that from here http://www.eleicoes.mai.gov.pt/autarquicas2013/candidatos.html

# %%
# If the default User-Agent header is used, the request is not successful.
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36'}

number_of_pages = 28
url_template = 'http://www.eleicoes.mai.gov.pt/autarquicas2013/static-data/candidates/PARTIES-CANDIDATES-CM-PAGE-{}.json'

# %%
# Each member of the list is a dict describing the candidates for each municipilaty
all_candidates = []

for i in range(1,number_of_pages + 1):
    result = requests.get(url_template.format(i), headers=headers)
    
    all_candidates += result.json()['electionCandidates']

# %%
result = requests.get(url_template.format(1), headers=headers)
parties = result.json()['parties']

# %%
# Check if the "alternateCandidates" value is ever not None
for munipality in all_candidates:
    for candidate in munipality['candidates']:
        if candidate['alternateCandidates'] is not None:
            print 'There is some alternate candidate'
            
# Ok, it never is

# Check if the there is ever more than one candidate
for munipality in all_candidates:
    for candidate in munipality['candidates']:
        if len(candidate['effectiveCandidates']) != 1:
            print 'There is more than one effective candidate'

# %%
# Prepare to transform to DataFrame
processed_candidates = []

for municipality in all_candidates:
    ine_id = get_ine_id(municipality['territoryKey'])
    
    for candidate in municipality['candidates']:
        party = normalize_party_names(candidate['party'])
        name = correct_names_encoding_problems(candidate['effectiveCandidates'][0])
        
        candidate_info= {'INE_ID': ine_id, 
                         'party': party,
                         'candidate_name': name}
        
        processed_candidates.append(candidate_info)

# %%
# Transform to DataFrame
candidates_df = DataFrame(processed_candidates)

# %%
# Correct Party symbols

def correct_party_name(candidate_name, correct_party_name):
    index = candidates_df[candidates_df.candidate_name == candidate_name].index[0]
    candidates_df.set_value(col='party', index=index, value=correct_party_name)

correct_party_name(u"Rui de Carvalho de Araújo Moreira", 'RM')
correct_party_name(u"Marco Paulo Caldeira de Almeida", 'scma')
correct_party_name(u"António Gordinho Trindade", 'gcicn')
correct_party_name(u"Aníbal Manuel Guerreiro Cordeiro", 'MIG')
correct_party_name(u"José Guilherme Aguiar", 'GAIA')
correct_party_name(u"Inácio José Ludovico Esperança", 'MUC')
correct_party_name(u"Nuno Miguel da Silva Pinhão Dâmaso Fazenda", 'MICA2013')
correct_party_name(u"Avelino Ferreira Torres", 'mccft')
correct_party_name(u"Aurélio Pedro Monteiro Ferreira", 'MpM')

# %%
# Add year column
candidates_df['year'] = 2013

# %%
# Title Case all candidate names
candidates_df.candidate_name = candidates_df.candidate_name.apply(lambda name: name.title())

# Upper case all party initials
candidates_df.party = candidates_df.party.apply(lambda paty: paty.upper())

# %%
candidates_df
# Out:
#       INE_ID                                     candidate_name  \
# 0        101                           Nelson Manuel Nunes Leal
# 1        101                       Maria Paula Da Graça Cardoso
# 2        101                      Gil Nadais Resende Da Fonseca
# 3        102            Rui Manuel Pinto Chagas Câncio Ferreira
# 4        102           António Augusto Amaral Loureiro E Santos
# 5        102                           Bruno Miguel Alves Bento
# 6        102                       José Licínio Tavares Pimenta
# 7        102                  Elísio Apolinário Simões Da Silva
# 8        103       João Tiago Castelo Branco Charuca De Azevedo
# 9        103                 Maria Teresa Belém Correia Cardoso
# 10       103  Maria De Fátima Gomes Martins Da Costa Henriqu...
# 11       103                 José Manuel Ferreira Nunes Ribeiro
# 12       103                        Lino Jorge Cerveira Pintado
# 13       104                           Adriano De Jesus Brandão
# 14       104                Francisco Manuel Da Cunha Gonçalves
# 15       104                           José Luís Alves Da Silva
# 16       104                           José Artur Tavares Neves
# 17       105                     Nelson Ricardo Esteves Peralta
# 18       105                        Élio Manuel Delgado Da Maia
# 19       105                        Miguel Lopes Batista Viegas
# 20       105            Luís Fernando Ferreira Monteiro Rebocho
# 21       105               Vitor Manuel Duarte Ferreira Ramalho
# 22       105                       José Agostinho Ribau Esteves
# 23       105                  Eduardo Elísio Silva Peralta Feio
# 24       106                    Abílio Augusto Carrazedo Guerra
# 25       106            Paulo Fernando Nogueira Martel Da Silva
# 26       106                             Manuel Da Rocha Vieira
# 27       106              Norberto Dos Santos Rodrigues Moreira
# 28       106                 Gonçalo Fernando Da Rocha De Jesus
# 29       107                    António Manuel De Sousa Andrade
# ...      ...                                                ...
# 1319    4302               Roberto Lúcio Silva Pereira Monteiro
# 1320    4401                        João Manuel De Melo Picanço
# 1321    4401                      João Manuel Bettencourt Cunha
# 1322    4401                         Manuel Avelar Cunha Santos
# 1323    4501                       Décio Natálio Almada Pereira
# 1324    4501                        Aires António Fagundes Reis
# 1325    4501                       António Vitorino Da Silveira
# 1326    4502                 Luís Virgílio De Sousa Da Silveira
# 1327    4502              Paulo Alberto Bettencourt Da Silveira
# 1328    4502                 João Paulo Bettencourt De Oliveira
# 1329    4601                   José Lourenço De Freitas Azevedo
# 1330    4601                           Cláudio José Gomes Lopes
# 1331    4601                   Roberto Manuel Medeiros Da Silva
# 1332    4602               Maria De Lurdes Rodrigues Luís Silva
# 1333    4602                    Sérgio Manuel Goulart Gonçalves
# 1334    4602                         José António Marcos Soares
# 1335    4602                         Miguel António Moniz Costa
# 1336    4603                        José Manuel Xavier De Ávila
# 1337    4603                  Luís Filipe Ramos Macedo Da Silva
# 1338    4603                              Mark Anthony Silveira
# 1339    4701  João Ângelo Stattmiller Saldanha Albuquerque N...
# 1340    4701                      Maria Do Céu Barroca De Brito
# 1341    4701                         Luís Carlos Correia Garcia
# 1342    4701                        José Leonardo Goulart Silva
# 1343    4801                          Alice Correia Rocha Ramos
# 1344    4801                         Luís Carlos Martins Maciel
# 1345    4802                             William Resendes Braga
# 1346    4802                        José Carlos Pimentel Mendes
# 1347    4901                           José Manuel Avelar Nunes
# 1348    4901                         José Manuel Alves Da Silva
#
#                    party  year
# 0                PCP-PEV  2013
# 1         PPD/PSD.CDS-PP  2013
# 2                     PS  2013
# 3                   B.E.  2013
# 4                 CDS-PP  2013
# 5                PCP-PEV  2013
# 6                PPD/PSD  2013
# 7                     PS  2013
# 8                 CDS-PP  2013
# 9                    III  2013
# 10               PCP-PEV  2013
# 11               PPD/PSD  2013
# 12                    PS  2013
# 13                CDS-PP  2013
# 14               PCP-PEV  2013
# 15               PPD/PSD  2013
# 16                    PS  2013
# 17                  B.E.  2013
# 18                    IX  2013
# 19               PCP-PEV  2013
# 20             PCTP/MRPP  2013
# 21                P.N.R.  2013
# 22    PPD/PSD.CDS-PP.PPM  2013
# 23                    PS  2013
# 24                  B.E.  2013
# 25                CDS-PP  2013
# 26               PCP-PEV  2013
# 27               PPD/PSD  2013
# 28                    PS  2013
# 29                  B.E.  2013
# ...                  ...   ...
# 1319                  PS  2013
# 1320                   I  2013
# 1321             PPD/PSD  2013
# 1322                  PS  2013
# 1323                   I  2013
# 1324             PPD/PSD  2013
# 1325                  PS  2013
# 1326              CDS-PP  2013
# 1327             PPD/PSD  2013
# 1328                  PS  2013
# 1329              CDS-PP  2013
# 1330             PPD/PSD  2013
# 1331                  PS  2013
# 1332              CDS-PP  2013
# 1333             PCP-PEV  2013
# 1334             PPD/PSD  2013
# 1335                  PS  2013
# 1336              CDS-PP  2013
# 1337             PPD/PSD  2013
# 1338                  PS  2013
# 1339                B.E.  2013
# 1340             PCP-PEV  2013
# 1341  PPD/PSD.CDS-PP.PPM  2013
# 1342                  PS  2013
# 1343             PPD/PSD  2013
# 1344                  PS  2013
# 1345      PPD/PSD.CDS-PP  2013
# 1346                  PS  2013
# 1347             PPD/PSD  2013
# 1348                  PS  2013
#
# [1349 rows x 4 columns]

# %%
candidates_df = candidates_df.set_index(['INE_ID'])
candidates_df.to_csv('data/processed_data/local_elections_candidates_2013.csv', encoding='utf-8')
