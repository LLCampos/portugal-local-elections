# %%
import requests

# %%
"""Objective: obtain the names of all candidates to president of "Câmara Municpal" in the 2013 Portuguese Local 
Elections. Goint to crawl that from here http://www.eleicoes.mai.gov.pt/autarquicas2013/candidatos.html"""
# Out:
# 'Objective: obtain the names of all candidates to president of "C\xc3\xa2mara Municpal" in the 2013 Portuguese Local \nElections. Goint to crawl that from here http://www.eleicoes.mai.gov.pt/autarquicas2013/candidatos.html '

# %%
# If the default User-Agent header is used, the request is not successful.
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36'}

number_of_pages = 28
url_template = 'http://www.eleicoes.mai.gov.pt/autarquicas2013/static-data/candidates/PARTIES-CANDIDATES-CM-PAGE-{}.json'

# %%
result.json()
# Out:
# {u'electionCandidates': [{u'candidates': [{u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Nelson Manuel Nunes Leal'],
#      u'mandates': 0,
#      u'party': u'PCP - PEV',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Maria Paula da Gra\xc3\xa7a Cardoso'],
#      u'mandates': 2,
#      u'party': u'PPD/PSD.CDS-PP',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Gil Nadais Resende da Fonseca'],
#      u'mandates': 5,
#      u'party': u'PS',
#      u'presidents': 1,
#      u'url': None}],
#    u'parentTerritoryName': u'Aveiro',
#    u'territoryKey': u'LOCAL-010100',
#    u'territoryName': u'\xc3\x81gueda'},
#   {u'candidates': [{u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Rui Manuel Pinto Chagas C\xc3\xa2ncio Ferreira'],
#      u'mandates': 0,
#      u'party': u'B.E.',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Ant\xc3\xb3nio Augusto Amaral Loureiro e Santos'],
#      u'mandates': 4,
#      u'party': u'CDS-PP',
#      u'presidents': 1,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Bruno Miguel Alves Bento'],
#      u'mandates': 0,
#      u'party': u'PCP - PEV',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Jos\xc3\xa9 Lic\xc3\xadnio Tavares Pimenta'],
#      u'mandates': 3,
#      u'party': u'PPD/PSD',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'El\xc3\xadsio Apolin\xc3\xa1rio Sim\xc3\xb5es da Silva'],
#      u'mandates': 0,
#      u'party': u'PS',
#      u'presidents': 0,
#      u'url': None}],
#    u'parentTerritoryName': u'Aveiro',
#    u'territoryKey': u'LOCAL-010200',
#    u'territoryName': u'Albergaria-a-Velha'},
#   {u'candidates': [{u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Jo\xc3\xa3o Tiago Castelo Branco Charuca de Azevedo'],
#      u'mandates': 0,
#      u'party': u'CDS-PP',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Maria Teresa Bel\xc3\xa9m Correia Cardoso'],
#      u'mandates': 3,
#      u'party': u'III',
#      u'presidents': 1,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Maria de F\xc3\xa1tima Gomes Martins da Costa Henriques Flores'],
#      u'mandates': 0,
#      u'party': u'PCP - PEV',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Jos\xc3\xa9 Manuel Ferreira Nunes Ribeiro'],
#      u'mandates': 3,
#      u'party': u'PPD/PSD',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Lino Jorge Cerveira Pintado'],
#      u'mandates': 1,
#      u'party': u'PS',
#      u'presidents': 0,
#      u'url': None}],
#    u'parentTerritoryName': u'Aveiro',
#    u'territoryKey': u'LOCAL-010300',
#    u'territoryName': u'Anadia'},
#   {u'candidates': [{u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Adriano de Jesus Brand\xc3\xa3o'],
#      u'mandates': 0,
#      u'party': u'CDS-PP',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Francisco Manuel da Cunha Gon\xc3\xa7alves'],
#      u'mandates': 0,
#      u'party': u'PCP - PEV',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Jos\xc3\xa9 Lu\xc3\xads Alves da Silva'],
#      u'mandates': 2,
#      u'party': u'PPD/PSD',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Jos\xc3\xa9 Artur Tavares Neves'],
#      u'mandates': 5,
#      u'party': u'PS',
#      u'presidents': 1,
#      u'url': None}],
#    u'parentTerritoryName': u'Aveiro',
#    u'territoryKey': u'LOCAL-010400',
#    u'territoryName': u'Arouca'},
#   {u'candidates': [{u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Nelson Ricardo Esteves Peralta'],
#      u'mandates': 0,
#      u'party': u'B.E.',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'\xc3\x89lio Manuel Delgado da Maia'],
#      u'mandates': 1,
#      u'party': u'IX',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Miguel Lopes Batista Viegas'],
#      u'mandates': 0,
#      u'party': u'PCP - PEV',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Lu\xc3\xads Fernando Ferreira Monteiro Rebocho'],
#      u'mandates': 0,
#      u'party': u'PCTP/MRPP',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Vitor Manuel Duarte Ferreira Ramalho'],
#      u'mandates': 0,
#      u'party': u'PNR',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Jos\xc3\xa9 Agostinho Ribau Esteves'],
#      u'mandates': 5,
#      u'party': u'PPD/PSD.CDS-PP.PPM',
#      u'presidents': 1,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Eduardo El\xc3\xadsio Silva Peralta Feio'],
#      u'mandates': 3,
#      u'party': u'PS',
#      u'presidents': 0,
#      u'url': None}],
#    u'parentTerritoryName': u'Aveiro',
#    u'territoryKey': u'LOCAL-010500',
#    u'territoryName': u'Aveiro'},
#   {u'candidates': [{u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Ab\xc3\xadlio Augusto Carrazedo Guerra'],
#      u'mandates': 0,
#      u'party': u'B.E.',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Paulo Fernando Nogueira Martel da Silva'],
#      u'mandates': 0,
#      u'party': u'CDS-PP',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Manuel da Rocha Vieira'],
#      u'mandates': 0,
#      u'party': u'PCP - PEV',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Norberto dos Santos Rodrigues Moreira'],
#      u'mandates': 3,
#      u'party': u'PPD/PSD',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Gon\xc3\xa7alo Fernando da Rocha de Jesus'],
#      u'mandates': 4,
#      u'party': u'PS',
#      u'presidents': 1,
#      u'url': None}],
#    u'parentTerritoryName': u'Aveiro',
#    u'territoryKey': u'LOCAL-010600',
#    u'territoryName': u'Castelo de Paiva'},
#   {u'candidates': [{u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Ant\xc3\xb3nio Manuel de Sousa Andrade'],
#      u'mandates': 0,
#      u'party': u'B.E.',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Diogo Silva Pardilh\xc3\xb3 Duarte de Campos'],
#      u'mandates': 0,
#      u'party': u'CDS-PP',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Fausto Manuel da Silva Neves'],
#      u'mandates': 0,
#      u'party': u'PCP - PEV',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Joaquim Jos\xc3\xa9 Pinto Moreira'],
#      u'mandates': 4,
#      u'party': u'PPD/PSD',
#      u'presidents': 1,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Jos\xc3\xa9 Barbosa da Mota'],
#      u'mandates': 3,
#      u'party': u'PS',
#      u'presidents': 0,
#      u'url': None}],
#    u'parentTerritoryName': u'Aveiro',
#    u'territoryKey': u'LOCAL-010700',
#    u'territoryName': u'Espinho'},
#   {u'candidates': [{u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Jos\xc3\xa9 Artur Pereira de Pinho'],
#      u'mandates': 0,
#      u'party': u'I',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Am\xc3\xa9rico Rodrigues Soares'],
#      u'mandates': 0,
#      u'party': u'PCP - PEV',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Diamantino Manuel Sabina'],
#      u'mandates': 4,
#      u'party': u'PPD/PSD.CDS-PP',
#      u'presidents': 1,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Fernando Manuel Mendon\xc3\xa7a Albergaria Matos'],
#      u'mandates': 3,
#      u'party': u'PS',
#      u'presidents': 0,
#      u'url': None}],
#    u'parentTerritoryName': u'Aveiro',
#    u'territoryKey': u'LOCAL-010800',
#    u'territoryName': u'Estarreja'},
#   {u'candidates': [{u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Ant\xc3\xb3nio Manuel Mendes Torres'],
#      u'mandates': 0,
#      u'party': u'B.E.',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Manuel Jos\xc3\xa9 Alferes Pereira'],
#      u'mandates': 0,
#      u'party': u'CDS-PP',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Antero de Oliveira Resende'],
#      u'mandates': 0,
#      u'party': u'PCP - PEV',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Em\xc3\xaddio Ferreira dos Santos Sousa'],
#      u'mandates': 6,
#      u'party': u'PPD/PSD',
#      u'presidents': 1,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Eduardo Marques dos Santos Cavaco'],
#      u'mandates': 5,
#      u'party': u'PS',
#      u'presidents': 0,
#      u'url': None}],
#    u'parentTerritoryName': u'Aveiro',
#    u'territoryKey': u'LOCAL-010900',
#    u'territoryName': u'Santa Maria da Feira'},
#   {u'candidates': [{u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Pedro Miguel de Pinho Tavares'],
#      u'mandates': 0,
#      u'party': u'B.E.',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Armindo Valente Domingues Prina'],
#      u'mandates': 0,
#      u'party': u'CDS-PP',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Jo\xc3\xa3o da Cruz Coquim'],
#      u'mandates': 0,
#      u'party': u'PCP - PEV',
#      u'presidents': 0,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Fernando Fidalgo Ca\xc3\xa7oilo'],
#      u'mandates': 4,
#      u'party': u'PPD/PSD',
#      u'presidents': 1,
#      u'url': None},
#     {u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Jos\xc3\xa9 Marinho Vaz'],
#      u'mandates': 3,
#      u'party': u'PS',
#      u'presidents': 0,
#      u'url': None}],
#    u'parentTerritoryName': u'Aveiro',
#    u'territoryKey': u'LOCAL-011000',
#    u'territoryName': u'\xc3\x8dlhavo'},
#   {u'candidates': [{u'alternateCandidates': None,
#      u'effectiveCandidates': [u'Ricardo Sequeiros Coelho'],
#      u'mandates': 0,
#      u'party': u'B.E.',
#      u'presidents': 0,
#      u'url': None}],
#    u'parentTerritoryName': u'Aveiro',
#    u'territoryKey': u'LOCAL-011100',
#    u'territoryName': u'Mealhada'}],
#  u'numberOfPages': 28,
#  u'page': 1,
#  u'parties': [{u'acronym': u'B.E.', u'name': u'Bloco de esquerda'},
#   {u'acronym': u'CDS-PP', u'name': u'CDS-PARTIDO POPULAR'},
#   {u'acronym': u'CDS-PP.MPT', u'name': u'"POR CONST\xc3\x82NCIA"'},
#   {u'acronym': u'CDS-PP.MPT.PPM', u'name': u'"Odivelas Merece Mais"'},
#   {u'acronym': u'CDS-PP.PPD/PSD', u'name': u'"DESENVOLVER PORTEL"'},
#   {u'acronym': u'I', u'name': u'"Amigos do Po\xc3\xa7o do Canto" - APC'},
#   {u'acronym': u'II', u'name': u'JPP - Juntos Pelo Povo Santa Cruz'},
#   {u'acronym': u'III',
#    u'name': u'Lista Independente de Fornelo e Vair\xc3\xa3o (LIFV)'},
#   {u'acronym': u'IV', u'name': u'MIV - Movimento Independente Vilarmourense'},
#   {u'acronym': u'IX', u'name': u'S\xc3\x83O MARTINHO SEMPRE - SMS'},
#   {u'acronym': u'MPT', u'name': u'PARTIDO DA TERRA'},
#   {u'acronym': u'PAN', u'name': u'Partido pelos Animais e pela Natureza'},
#   {u'acronym': u'PCP - PEV',
#    u'name': u'CDU - Coliga\xc3\xa7\xc3\xa3o Democr\xc3\xa1tica Unit\xc3\xa1ria'},
#   {u'acronym': u'PCTP/MRPP',
#    u'name': u'PARTIDO COMUNISTA DOS TRABALHADORES PORTUGUESES'},
#   {u'acronym': u'PND', u'name': u'NOVA DEMOCRACIA'},
#   {u'acronym': u'PNR', u'name': u'PARTIDO NACIONAL RENOVADOR'},
#   {u'acronym': u'PPD/PSD', u'name': u'PARTIDO SOCIAL DEMOCRATA'},
#   {u'acronym': u'PPD/PSD.CDS-PP', u'name': u'GAIA NA FRENTE'},
#   {u'acronym': u'PPD/PSD.CDS-PP.MPT',
#    u'name': u'&lt;&lt;SINTRA PODE MAIS&gt;&gt;'},
#   {u'acronym': u'PPD/PSD.CDS-PP.MPT.PPM', u'name': u'"MOVIMENTO POR TAVIRA"'},
#   {u'acronym': u'PPD/PSD.CDS-PP.PPM', u'name': u'"SOMOS BARCELOS"'},
#   {u'acronym': u'PPD/PSD.CDS-PP.PPM.MPT', u'name': u'"SOMOS FIGUEIRA"'},
#   {u'acronym': u'PPD/PSD.MPT', u'name': u'"TODOS POR ALPIAR\xc3\x87A"'},
#   {u'acronym': u'PPD/PSD.MPT.PPM', u'name': u'"LOURES SABE MUDAR"'},
#   {u'acronym': u'PPD/PSD.PPM', u'name': u'"MANTER A ESPERAN\xc3\x87A"'},
#   {u'acronym': u'PPD/PSD.PPM.MPT', u'name': u'"PORTO FORTE"'},
#   {u'acronym': u'PPM', u'name': u'PARTIDO POPULAR MON\xc3\x81RQUICO'},
#   {u'acronym': u'PPM/PPV/PND', u'name': u'"PLATAFORMA DE CIDADANIA LAGOS"'},
#   {u'acronym': u'PPM-PPV', u'name': u'"ESP\xc3\x8dRITO DE GUIMAR\xc3\x83ES"'},
#   {u'acronym': u'PPV', u'name': u'PORTUGAL pro VIDA'},
#   {u'acronym': u'PS', u'name': u'PARTIDO SOCIALISTA'},
#   {u'acronym': u'PS-BE-PND-MPT-PTP-PAN', u'name': u'"MUDAN\xc3\x87A"'},
#   {u'acronym': u'PS-PTP-PND-BE', u'name': u'"PELA MUDAN\xc3\x87A"'},
#   {u'acronym': u'PTP', u'name': u'PARTIDO TRABALHISTA PORTUGU\xc3\x8aS'},
#   {u'acronym': u'V', u'name': u'MaisEstrela'},
#   {u'acronym': u'VI',
#    u'name': u'MDA XXI MOVIMENTO DEMOCR\xc3\x81TICO ALTERNATIVO'},
#   {u'acronym': u'VII', u'name': u'LISTA  INDEPENDENTE DE PASSOS'},
#   {u'acronym': u'VIII',
#    u'name': u'\xc3\x81gua Longa \xc3\x89 de Todos - ALEDT'},
#   {u'acronym': u'X',
#    u'name': u'MOREIRA O LIMA E CABRA\xc3\x87\xc3\x83O UNIDOS (MCU)'},
#   {u'acronym': u'XI',
#    u'name': u'UTD - Uni\xc3\xa3o Trabalho e Dedica\xc3\xa7\xc3\xa3o'},
#   {u'acronym': u'XII', u'name': u'Unidos por Serro Ventoso - IUSV'},
#   {u'acronym': u'XIII',
#    u'name': u'MAI MOVIMENTO AUT\xc3\x81RQUICO INDEPENDENTE'},
#   {u'acronym': u'XIX', u'name': u'LISTA  INDEPENDENTE POR MEDELO'},
#   {u'acronym': u'XV', u'name': u'IPM INDEPENDENTES POR MEDELO'},
#   {u'acronym': u'XVI', u'name': u'5 Pelo C\xc3\xa2stelo'},
#   {u'acronym': u'XVII', u'name': u'Um Rumo ao Futuro - RF'},
#   {u'acronym': u'XVIII', u'name': u'Unidos pela Freguesia - UPF'},
#   {u'acronym': u'XX',
#    u'name': u'Independentes "Por Vilarinho de S\xc3\xa3o Rom\xc3\xa3o"'}]}
